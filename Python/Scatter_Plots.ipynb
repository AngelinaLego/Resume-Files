# %%
import matplotlib.pyplot as plt

# %%
x = range(0, 10)
y = ([2 * value for value in x])
plt.scatter(x, y) # or plt.plot(x, y)
plt.axis('equal')
plt.show()

# %%
def is_in_interval(number, minimum, maximum):
  return minimum <= number <= maximum
# defined on page 13 chapter 1

plt.plot(x, y)
where = [is_in_interval(value, 2, 6) for value in x]
plt.fill_between(x, y, where=where)
plt.show()

# %%
plt.scatter(x, y)
plt.plot(x, y)
plt.fill_between(x, y, where=where)
plt.xlabel('Value between zero and ten')
plt.ylabel('Twice the values of x')
plt.show()

# %% [markdown]
# ---
# Summary:
#
# Learned how to draw and display scatter plots using matplotlib function.
# Transform x-axis and y-axis and their ranges.
#
# Performing data filtering, transformation, and hightliting the area or range that are needed.
#
# Using (plt.fill_between) function to shade the area in the range.
