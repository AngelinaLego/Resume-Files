# %% [markdown]
# Q2. How do we plot coin-flip probabilituies with Matplotlib?

# %%
from itertools import product # see p. 9 for this tine
from collections import defaultdict # see p. 11 for this line

# %%
def generate_coin_sample_space(num_flips = 10):
  weighted_sample_space = defaultdict(int)
  for coin_flips in product( ['Heads', 'Tails'], repeat = num_flips):
    heads_count = len([outcome for outcome in coin_flips if outcome == 'Heads'])
    weighted_sample_space[heads_count] += 1
  return weighted_sample_space

weighted_sample_space = generate_coin_sample_space() # see p. 14 for all this
weighted_sample_space
# Out:
# defaultdict(int,
#             {10: 1,
#              9: 10,
#              8: 45,
#              7: 120,
#              6: 210,
#              5: 252,
#              4: 210,
#              3: 120,
#              2: 45,
#              1: 10,
#              0: 1})

# %%
import matplotlib.pyplot as plt

x_10_flips = list(weighted_sample_space.keys())
y_10_flips = [weighted_sample_space[key] for key in x_10_flips]

plt.scatter(x_10_flips, y_10_flips)
plt.xlabel('Head-count')
plt.ylabel('Number of coin-flip combinations with x heads')
plt.show()

# %%
sample_space_size = sum(weighted_sample_space.values())
prob_x_10_flips = [values / sample_space_size for values in y_10_flips]
plt.scatter(x_10_flips, prob_x_10_flips)
plt.xlabel('Head-count')
plt.ylabel('Probability')
plt.show()

# %%
assert sum(prob_x_10_flips) == 1.0

# %%
def is_in_interval(number, minimum, maximum):
  return minimum <= number <= maximum
plt.plot(x_10_flips, prob_x_10_flips)
plt.scatter(x_10_flips, prob_x_10_flips)
where = [is_in_interval(value, 8, 10) for value in x_10_flips]
plt.fill_between(x_10_flips, prob_x_10_flips, where=where)
plt.xlabel('Head-count')
plt.ylabel('Probability')
plt.show()

# %%
plt.plot(x_10_flips, prob_x_10_flips)
plt.scatter(x_10_flips, prob_x_10_flips)
where = [not is_in_interval(value, 3, 7) for value in x_10_flips]
plt.fill_between(x_10_flips, prob_x_10_flips, where=where)
plt.xlabel('Head-count')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# ----
# Summary:
#
# Continuing to build on the previous knowledge about the scatter plots but more focusing on advanced data operations and statistical analysis. For example,
#
# Simulated heads&Rails by using defaultdict(int) for initializing a dictionary where keys are counts of "Heads" and values are the number of ways that count happens.
#
# Then we are finding a ceratin number of head counts (x_10_flips) from the generated sample space and creating the scatter plot for this data.
# Then we are computing the total number of sequences and finding the probability of the needed outcome.
#
# Finally, giving our function (is_in_interval) the limits where the data schould be found and plotting it. For the last one, increasing the range and probability, which will be marked on the scatter plot as well. Using (plt.fill_between) shading the outside area of the range.
#
#
#
#
# ----
